# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator

# %%
save_path = r"C:\Users\hugo\OneDrive\Documents\Quantitative Finance\Thesis\Plots"
colors = ['#d7191c','#fdae61','#abd9e9','#2c7bb6']

# %%
# history = pd.read_pickle(r"C:\Users\hugo\OneDrive\Documents\Quantitative Finance\Thesis\Data\history_ANN_old.pkl")
history = pd.read_pickle('ANN_training_history.pkl')

# %%
history.index += 1

# %%
ax = plt.subplot()

plt.plot(history['loss'], color=colors[3], ls='-.')
plt.plot(history['val_loss'], color=colors[0])
ax.xaxis.set_minor_locator(MultipleLocator(5))

plt.xlim(-2, len(history))
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')

labels = ['Training data', 'Validation data']
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.18), labels=labels, ncol=2)

plt.grid(alpha=.5)

# plt.savefig(save_path + '/cost_function.eps', bbox_inches='tight')
