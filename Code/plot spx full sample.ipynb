# %%
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator
import datetime

save_path = r"C:\Users\hugo\OneDrive\Documents\Quantitative Finance\Thesis\Plots"
data_path = r"C:\Users\hugo\OneDrive\Documents\Quantitative Finance\Thesis\data\results"
colors = ['#d7191c','#fdae61','#abd9e9','#2c7bb6']

# %%
def read_process_pickle(path, moving_window):
    df = pd.read_pickle(path)
    df = remove_outliers(df)
    return df.rolling(window=moving_window).mean()

def remove_outliers(df_input):
    df = df_input.copy()
    df = df.loc[df['v'] > .01]
    df = df.loc[df['rho'].abs()<.99]
    df = df.loc[df['alpha'] > .01]
    
    df = df.loc[df['delta'] > .2]
    df = df.loc[df['delta'] < 1]
    
    return df

# %%
window = 20

spx_hagan = read_process_pickle(data_path + '\spx_30d_hagan.pkl', window)
spx_ann = read_process_pickle(data_path + '\spx_30d_ann.pkl', window)
spx_antonov = read_process_pickle(data_path + '\spx_30d_antonov.pkl', window)

# %% [markdown]
# ## Short term SPX

# %% [markdown]
# ### $\alpha$

# %%
ax = plt.subplot()
plt.plot(spx_antonov['alpha'], color=colors[0])
plt.plot(spx_ann['alpha'], color=colors[-1], ls='-.')
plt.plot(spx_hagan['alpha'], color=colors[1], ls=':')


years = mdates.YearLocator(1)
months = mdates.MonthLocator(interval=1)
plt.xticks(rotation=25)

plt.xlim(datetime.datetime(2010,1,1), datetime.datetime(2020,12,31))
plt.xlabel('Date')
plt.ylabel(r'$\alpha$')
labels = ['Antonov', 'Antonov ANN', 'Hagan']
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.18), labels=labels, ncol=3)
plt.grid()

ax.xaxis.set_major_locator(years)
myFmt = mdates.DateFormatter('%Y')
ax.xaxis.set_major_formatter(myFmt)

plt.savefig(save_path + '/spx_full_alpha.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### $\rho $

# %%
ax = plt.subplot()
# plt.plot(spx_ann['rho'], color=colors[3])
# plt.plot(spx_hagan['rho'], color=colors[0], ls='-.')

plt.plot(spx_antonov['rho'], color=colors[0])
plt.plot(spx_ann['rho'], color=colors[-1], ls='-.')
plt.plot(spx_hagan['rho'], color=colors[1], ls=':')

years = mdates.YearLocator(1)
months = mdates.MonthLocator(interval=1)
plt.xticks(rotation=25)

labels = ['Antonov', 'Antonov ANN', 'Hagan']
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.18), labels=labels, ncol=3)

plt.xlim(datetime.datetime(2010,1,1), datetime.datetime(2020,12,31))
plt.xlabel('Date')
plt.ylabel(r'$\rho$')
plt.grid()

ax.xaxis.set_major_locator(years)
myFmt = mdates.DateFormatter('%Y')
ax.xaxis.set_major_formatter(myFmt)

# plt.savefig(save_path + '/spx_full_rho.eps', bbox_inches='tight')

# %% [markdown]
# ### $v$

# %%
ax = plt.subplot()
# plt.plot(spx_ann['v'], color=colors[3])
# plt.plot(spx_hagan['v'], color=colors[0], ls='-.')
# plt.plot(spx_antonov['v'], color='green', ls='-.')


plt.plot(spx_antonov['v'], color=colors[0])
plt.plot(spx_ann['v'], color=colors[-1], ls='-.')
plt.plot(spx_hagan['v'], color=colors[1], ls=':')

years = mdates.YearLocator(1)
months = mdates.MonthLocator(interval=1)
plt.xticks(rotation=25)

labels = ['Antonov', 'Antonov ANN', 'Hagan']
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.18), labels=labels, ncol=3)

plt.xlim(datetime.datetime(2010,1,1), datetime.datetime(2020,12,31))
plt.xlabel('Date')
plt.ylabel(r'$v$')
plt.grid()

ax.xaxis.set_major_locator(years)
myFmt = mdates.DateFormatter('%Y')
ax.xaxis.set_major_formatter(myFmt)

plt.savefig(save_path + '/spx_full_v.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Delta

# %%
ax = plt.subplot()
# plt.plot(spx_ann['delta'], color=colors[3])
# plt.plot(spx_hagan['delta'], color=colors[0], ls='-.')


plt.plot(spx_antonov['delta'], color=colors[0])
plt.plot(spx_ann['delta'], color=colors[-1], ls='-.')
plt.plot(spx_hagan['delta'], color=colors[1], ls=':')

years = mdates.YearLocator(1)
months = mdates.MonthLocator(interval=1)
plt.xticks(rotation=25)

labels = ['Antonov', 'Antonov ANN', 'Hagan']
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.18), labels=labels, ncol=3)

plt.xlim(datetime.datetime(2010,1,1), datetime.datetime(2020,12,31))
plt.xlabel('Date')
plt.ylabel(r'$\Delta$')
plt.grid()

ax.xaxis.set_major_locator(years)
myFmt = mdates.DateFormatter('%Y')
ax.xaxis.set_major_formatter(myFmt)

plt.savefig(save_path + '/spx_full_delta.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Vega

# %%
ax = plt.subplot()
# plt.plot(spx_ann['vega'], color=colors[3])
# plt.plot(spx_hagan['vega'], color=colors[0], ls='-.')
# plt.plot(spx_antonov['vega'], color=colors[1], ls='-.')

plt.plot(spx_antonov['vega'], color=colors[0])
plt.plot(spx_ann['vega'], color=colors[-1], ls='-.')
plt.plot(spx_hagan['vega'], color=colors[1], ls=':')


years = mdates.YearLocator(1)
months = mdates.MonthLocator(interval=1)
plt.xticks(rotation=25)

labels = ['Antonov', 'Antonov ANN', 'Hagan']
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.18), labels=labels, ncol=3)

plt.xlim(datetime.datetime(2010,1,1), datetime.datetime(2020,12,31))
plt.xlabel('Date')
plt.ylabel(r'$\mathcal{V}$')
plt.grid()

ax.xaxis.set_major_locator(years)
myFmt = mdates.DateFormatter('%Y')
ax.xaxis.set_major_formatter(myFmt)

plt.savefig(save_path + '/spx_full_vega.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
